# %% [markdown]
# # **Testing TimesFM**

# %% [markdown]
# ## Imports

# %%
# !pip install torch --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install timesfm[torch]

# %%
# !pip install "jax[cuda12]"==0.4.21 jaxlib==0.4.21

# %%
# !pip install numpy==1.26.4

# %%
# !pip install matplotlib

# %%
import timesfm
import pandas as pd
import joblib

import numpy as np

from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## **1** Ground water data

# %%
# Read the dataset
aquifer_by_stations = joblib.load('aquifer_by_stations.joblib')

# %%
aquifers_list = [85065, 85064]

# %%
aquifer_by_stations[85065]['altitude_diff'].values

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# %%
aquifers_list = [85065]
horizon = 5 # prediction horizon
day_len = 20 # number of days to forecast

# Define the model parameters
# For Torch
model = timesfm.TimesFm(
      hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          huggingface_repo_id="google/timesfm-1.0-200m-pytorch"),
  )


# List for r2 results for different prediction horizons
r2_scores = [[] for _ in range(horizon)]

for aquifer in aquifers_list:
    # List for storing the predictions
    predictions = [[] for _ in range(5)]

    scaler = StandardScaler()
    aquifer_by_stations[aquifer]['altitude_diff'] = scaler.fit_transform(aquifer_by_stations[aquifer]['altitude_diff'].values.reshape(-1, 1))

    # Iterate from day_len days before the end, to the last day
    for i in range(day_len + (horizon-1), 0, -1):
        y = aquifer_by_stations[aquifer]
        y = y.rename(columns={'date': 'ds', 'id': 'unique_id'})
        
        forecast = model.forecast_on_df(
            inputs=y[:-i],
            freq="D",
            value_name="altitude_diff",
            num_jobs=-1,
        )

        # Store the results for every prediction horizon separately
        for h in range(horizon):
            #print(forecast.head())
            predictions[h].append(scaler.inverse_transform(forecast['timesfm'].iloc[-horizon+h].reshape(-1, 1))[0][0])
    
    # Clean up the results
    predictions[0] = predictions[0][-day_len:]
    predictions[1] = predictions[1][3:-1]
    predictions[2] = predictions[2][2:-2]
    predictions[3] = predictions[3][1:-3]
    predictions[4] = predictions[4][0:-4]

    # Calculate the r2 scores and store them in a list
    for i in range(horizon):
        r2_scores[i].append(r2_score(aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], predictions[i]))

# %%
forecast

# %%
aquifer_by_stations[aquifer]['altitude_diff']

# %%
# Calculate the average r2 score
r2_average =  []
std_dev = []

for i in range(5):
    r2_average.append(np.mean(r2_scores[i]))
    std_dev.append(np.std(r2_scores[i]))

# %%
r2_average

# %%
plt.figure(figsize=(8, 4))
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], color="royalblue", label="true data")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[0], color="tomato", label="forecast0")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[1], color="orange", label="forecast1")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[2], color="green", label="forecast2")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[3], color="purple", label="forecast3")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[4], color="brown", label="forecast4")
plt.legend()
plt.grid()
plt.show()

# %%
# Save the average r2_scores
with open('../reports/timegpt-1/timegpt-ground-water-r2.txt', 'w') as file:
    for item in r2_average:
        file.write(f"{item}\n")

# %%
# Save the standar deviations
with open('../reports/timegpt-1/timegpt-ground-water-std-dev.txt', 'w') as file:
    for item in std_dev:
        file.write(f"{item}\n")

# %%
# Transpose the r2_scores list
r2_scores_transposed = [list(x) for x in zip(*r2_scores)]
# Pair up the stations with their r2_scores and store them in a dictionary
scores = dict(zip(aquifers_list, r2_scores_transposed))
scores

# %%
# Sort them by the value in r2_scores[0]
scores_sorted = {k: v for k, v in sorted(scores.items(), key=lambda item: item[1][0])}
scores_sorted

# %%
# Save the r2_scores
joblib.dump(scores_sorted, '../reports/timegpt-1/timegpt-ground-water-r2-stations')

# %%
a = [0, 1, 10, 200, -4, 88]
scaler = StandardScaler()
a_scaled = scaler.fit_transform(np.array(a).reshape(-1, 1))
a_scaled.reshape(-1)

# %% [markdown]
# ### Univariate ground water data 2nd try

# %%
# Read the dataset
aquifer_by_stations = joblib.load('aquifer_by_stations.joblib')

aquifers_list = [85065, 85064]
horizon = 5 # prediction horizon
day_len = 365 # number of days to forecast
context_len = 512

# Define the model parameters
# For Torch
model = timesfm.TimesFm(
      hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
          context_len=context_len
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          huggingface_repo_id="google/timesfm-1.0-200m-pytorch"),
  )


# List for r2 results for different prediction horizons
r2_scores = [[] for _ in range(horizon)]

for aquifer in aquifers_list:
    # List for storing the predictions
    predictions = [[] for _ in range(5)]

    scaler = StandardScaler()
    
    # Iterate from day_len days before the end, to the last day
    for i in range(day_len + (horizon-1), 0, -1):
        y = aquifer_by_stations[aquifer]
        y['altitude_diff'] = scaler.fit_transform(y['altitude_diff'].values.reshape(-1, 1))
        
        raw_forecast, _ = model.forecast(
          inputs=[y['altitude_diff'][:-i].values.tolist()], freq=[0] * len(y['altitude_diff'][:-i].values.tolist())
        )

        # Store the results for every prediction horizon separately
        for h in range(horizon):
            predictions[h].append(scaler.inverse_transform(raw_forecast[0][h].reshape(-1, 1))[0][0])
    
    for i in range(horizon):
        if i == 0:
            predictions[i] = predictions[i][-day_len:]
        else:
            predictions[i] = predictions[i][(horizon-i-1):-i]

    # Calculate the r2 scores and store them in a list
    for i in range(horizon):
        r2_scores[i].append(r2_score(aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], predictions[i]))

# %%
# Calculate the average r2 score
r2_average =  []
std_dev = []

for i in range(horizon):
    r2_average.append(np.mean(r2_scores[i]))
    std_dev.append(np.std(r2_scores[i]))

# %%
r2_average

# %% [markdown]
# ### Multivariate ground water data

# %%
# Get the data
aquifer_by_stations = joblib.load('../data/interim/ground-water-and-weather-no-new-features.joblib')

# Function to add the predictions
def weather_forecast(X):
    postfixes = ['avg', 'min', 'max']
    for postfix in postfixes:
        X[f"precipitation_probability_{postfix}_shift-{5}"] = X[f'precipitation_probability_{postfix}'].shift(-5)
        X[f"precipitation_intensity_{postfix}_shift-{5}"] = X[f'precipitation_intensity_{postfix}'].shift(-5)
    return X

aquifers_list = [85065, 85064]

# Add the weather forecast features
for aquifer in aquifers_list:
    aquifer_by_stations[aquifer] = weather_forecast(aquifer_by_stations[aquifer])
    aquifer_by_stations[aquifer] = aquifer_by_stations[aquifer][:-5]

# The additional parameters that will be used for training and prediction
additional_parameters = aquifer_by_stations[85065].columns.values.tolist()

# Clean up the list
parameters_to_delete = ['date', 'station_id', 'altitude', 'altitude_diff', 'id', 'location_id']
additional_parameters = [parameter for parameter in additional_parameters if parameter not in parameters_to_delete]

# Define the horizon and the day_len
'''horizon = 5
day_len = 100
test_len = 365
aquifers_list = [85065, 85064]'''

# Scale the additional features

'''for aquifer in aquifers_list:
    for feature in additional_parameters:
        scaler = StandardScaler()
        aquifer_by_stations[aquifer][feature] = scaler.fit_transform(aquifer_by_stations[aquifer][feature].values.reshape(-1, 1)).reshape(-1)'''

# %%
aquifers_list = [85065]
horizon = 1 # prediction horizon
day_len = 365 # number of days to forecast
context_len = 512

# Define the model parameters
# For Torch
model = timesfm.TimesFm(
      hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          huggingface_repo_id="google/timesfm-1.0-200m-pytorch"),
  )


# List for r2 results for different prediction horizons
r2_scores = [[] for _ in range(horizon)]

for aquifer in aquifers_list:
    # List for storing the predictions
    predictions = [[] for _ in range(5)]

    #scaler = StandardScaler()
    #aquifer_by_stations[aquifer]['altitude_diff'] = scaler.fit_transform(aquifer_by_stations[aquifer]['altitude_diff'].values.reshape(-1, 1))

    # Iterate from day_len days before the end, to the last day
    for i in range(day_len + (horizon-1), 0, -1):
        y = aquifer_by_stations[aquifer]
        
        '''raw_forecast, _ = model.forecast(
          inputs=[y['altitude_diff'][:-i].values.tolist()], freq=[0] * len(y['altitude_diff'][:-i].values.tolist())
        )'''

        cov_forecast, ols_forecast = model.forecast_with_covariates(  
              inputs=[y['altitude_diff'][-(context_len+i):-i].values.tolist()], # Wrap in list since inputs expects list of time series
              dynamic_numerical_covariates={
                      #"day_time": [[0]*horizon   + y["day_time"][:-i].values.tolist()],
                      "day_time": [[0]*horizon   + y["day_time"][-(context_len+i):-i].values.tolist()],
                      #"percipitation": [y["precipitation"][-(context_len+i):-i].values.tolist() + [y["precipitation"][-(context_len+i):-i].iloc[-1]]*horizon],
                      #"percipitation": [y["precipitation"][:-i].values.tolist() + [y["precipitation"][:-i].iloc[-2]]*5],
                      #"percipitation": [y["precipitation"][:-i].values.tolist() + [y["precipitation"][:-i].iloc[-3]]*5],
                      "snow_accumulation": [[0]*horizon + y["snow_accumulation"][-(context_len+i):-i].values.tolist()],
                      "temperature_avg": [[0]*horizon + y["temperature_avg"][-(context_len+i):-i].values.tolist()],
                      #"temperature_min": [[0]*horizon + y["temperature_min"][:-i].values.tolist()],
                      #"temperature_max": [[0]*horizon + y["temperature_max"][:-i].values.tolist()],
                      #"cloud_cover_avg": [[0]*horizon + y["cloud_cover_avg"][:-i].values.tolist()],
                      #"cloud_cover_min": [[0]*horizon + y["cloud_cover_min"][:-i].values.tolist()],
                      #"cloud_cover_max": [[0]*horizon + y["cloud_cover_max"][:-i].values.tolist()],
                      #"humidity_avg": [[0]*horizon + y["humidity_avg"][:-i].values.tolist()],
                      #"humidity_min": [[0]*horizon + y["humidity_min"][:-i].values.tolist()],
                      #"humidity_max": [[0]*horizon + y["humidity_max"][:-i].values.tolist()],
                      #"uv_index_avg": [[0]*horizon + y["uv_index_avg"][:-i].values.tolist()],
                      #"uv_index_min": [[0]*horizon + y["uv_index_min"][:-i].values.tolist()],
                      #"uv_index_max": [[0]*horizon + y["uv_index_max"][:-i].values.tolist()],
                      "precipitation_probability_avg": [[0]*horizon + y["precipitation_probability_avg"][-(context_len+i):-i].values.tolist()],
                      "precipitation_probability_min": [[0]*horizon + y["precipitation_probability_min"][-(context_len+i):-i].values.tolist()],
                      "precipitation_probability_max": [[0]*horizon + y["precipitation_probability_max"][-(context_len+i):-i].values.tolist()],
                      "precipitation_intensity_avg": [[0]*horizon + y["precipitation_intensity_avg"][-(context_len+i):-i].values.tolist()],
                      "precipitation_intensity_min": [[0]*horizon + y["precipitation_intensity_min"][-(context_len+i):-i].values.tolist()],
                      "precipitation_intensity_max": [[0]*horizon + y["precipitation_intensity_max"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_probability_avg_shift-5": [[0]*horizon + y["precipitation_probability_avg_shift-5"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_intensity_avg_shift-5": [[0]*horizon + y["precipitation_intensity_avg_shift-5"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_probability_min_shift-5": [[0]*horizon + y["precipitation_probability_min_shift-5"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_intensity_min_shift-5": [[0]*horizon + y["precipitation_intensity_min_shift-5"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_probability_max_shift-5": [[0]*horizon + y["precipitation_probability_max_shift-5"][-(context_len+i):-i].values.tolist()],
                      #"precipitation_intensity_max_shift-5": [[0]*horizon + y["precipitation_intensity_max_shift-5"][-(context_len+i):-i].values.tolist()],
                  },
              freq=[0] * len(y['altitude_diff'][:-i].values.tolist()),
              xreg_mode="timesfm + xreg",
              ridge=50.0,
              force_on_cpu=False,
              normalize_xreg_target_per_input=True,    # default
        )

        # Store the results for every prediction horizon separately
        for h in range(horizon):
            #predictions[h].append(scaler.inverse_transform(cov_forecast[0][h].reshape(-1, 1))[0][0])
            predictions[h].append(cov_forecast[0][h])
            #predictions[h].append(raw_forecast[0][h])
    
    for i in range(horizon):
        if i == 0:
            predictions[i] = predictions[i][-day_len:]
        else:
            predictions[i] = predictions[i][(horizon-i-1):-i]

    # Clean up the results
    '''predictions[0] = predictions[0][-day_len:]
    predictions[1] = predictions[1][3:-1]
    predictions[2] = predictions[2][2:-2]
    predictions[3] = predictions[3][1:-3]
    predictions[4] = predictions[4][0:-4]'''

    # Calculate the r2 scores and store them in a list
    for i in range(horizon):
        r2_scores[i].append(r2_score(aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], predictions[i]))

# %%
y = aquifer_by_stations[85065]
horizon = 3
i = 3
context_len = 5

[[0]*horizon   + y["day_time"][-(context_len+i):-i].values.tolist()]

# %%
# Calculate the average r2 score
r2_average =  []
std_dev = []

for i in range(horizon):
    r2_average.append(np.mean(r2_scores[i]))
    std_dev.append(np.std(r2_scores[i]))

# %%
r2_average

# %%
plt.figure(figsize=(8, 4))
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], color="royalblue", label="true data")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[0], color="tomato", label="forecast0")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[1], color="orange", label="forecast1")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[2], color="green", label="forecast2")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[3], color="purple", label="forecast3")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[4], color="brown", label="forecast4")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Multivariate with weather predictions

# %%
# Get the data
aquifer_by_stations = joblib.load('../data/interim/ground-water-and-weather-with-forecasts-and-additional-features.joblib')

# Define the horizon and the day_len
'''horizon = 5
day_len = 100
test_len = 365
aquifers_list = [85065, 85064]'''

# Scale the additional features

'''for aquifer in aquifers_list:
    for feature in additional_parameters:
        scaler = StandardScaler()
        aquifer_by_stations[aquifer][feature] = scaler.fit_transform(aquifer_by_stations[aquifer][feature].values.reshape(-1, 1)).reshape(-1)'''

# %%
aquifer_by_stations[85065].columns[-120:-100]

# %%
aquifers_list = [85065]
horizon = 5 # prediction horizon
day_len = 365 # number of days to forecast
context_len = 512

# Define the model parameters
# For Torch
model = timesfm.TimesFm(
      hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          huggingface_repo_id="google/timesfm-1.0-200m-pytorch"),
  )


# List for r2 results for different prediction horizons
r2_scores = [[] for _ in range(horizon)]

for aquifer in aquifers_list:
    # List for storing the predictions
    predictions = [[] for _ in range(5)]

    #scaler = StandardScaler()
    #aquifer_by_stations[aquifer]['altitude_diff'] = scaler.fit_transform(aquifer_by_stations[aquifer]['altitude_diff'].values.reshape(-1, 1))

    # Iterate from day_len days before the end, to the last day
    for i in range(day_len + (horizon-1), 0, -1):
        y = aquifer_by_stations[aquifer]
        
        '''raw_forecast, _ = model.forecast(
          inputs=[y['altitude_diff'][:-i].values.tolist()], freq=[0] * len(y['altitude_diff'][:-i].values.tolist())
        )'''

        covariates = {
            'rr_decodeText': []
        }
        for j in range(horizon+1):
            if j != 0:
                covariates['rr_decodeText'][0].append(aquifer_by_stations[aquifer][f'rr_decodeText_{j}'].iloc[-i])
            else:
                covariates['rr_decodeText'].append(aquifer_by_stations[aquifer][f'rr_decodeText_{j}'].iloc[-(context_len+i):-i].values.tolist())

        cov_forecast, ols_forecast = model.forecast_with_covariates(  
              inputs=[y['altitude_diff'][-(context_len+i):-i].values.tolist()], # Wrap in list since inputs expects list of time series
              dynamic_numerical_covariates= covariates,
              freq=[0] * len(y['altitude_diff'][-(context_len+i):-i].values.tolist()),
              xreg_mode="timesfm + xreg",
              ridge=0,
              force_on_cpu=False,
              normalize_xreg_target_per_input=True,    # default
        )

        # Store the results for every prediction horizon separately
        for h in range(horizon):
            #predictions[h].append(scaler.inverse_transform(cov_forecast[0][h].reshape(-1, 1))[0][0])
            predictions[h].append(cov_forecast[0][h])
            #predictions[h].append(raw_forecast[0][h])
    
    for i in range(horizon):
        if i == 0:
            predictions[i] = predictions[i][-day_len:]
        else:
            predictions[i] = predictions[i][(horizon-i-1):-i]

    # Calculate the r2 scores and store them in a list
    for i in range(horizon):
        r2_scores[i].append(r2_score(aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], predictions[i]))

# %%
cov_forecast

# %%
# Calculate the average r2 score
r2_average =  []
std_dev = []

for i in range(horizon):
    r2_average.append(np.mean(r2_scores[i]))
    std_dev.append(np.std(r2_scores[i]))

# %%
r2_average

# %%
plt.figure(figsize=(8, 4))
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], color="royalblue", label="true data")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[0], color="tomato", label="forecast0")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[1], color="orange", label="forecast1")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[2], color="green", label="forecast2")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[3], color="purple", label="forecast3")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[4], color="brown", label="forecast4")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(covariates['rr_decodeText'][0], color="darkgreen", label="rr_decodeText")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Multivariate with weather predictions v2

# %%
additional_parameters = [
 'altitude',
 'day_time',
 'precipitation',
 'snow_accumulation',
 'temperature_avg',
 'temperature_min',
 'temperature_max',
 'cloud_cover_avg',
 'cloud_cover_min',
 'cloud_cover_max',
 'humidity_avg',
 'humidity_min',
 'humidity_max',
 'uv_index_avg',
 'uv_index_min',
 'uv_index_max',
 'precipitation_probability_avg',
 'precipitation_probability_min',
 'precipitation_probability_max',
 'precipitation_intensity_avg',
 'precipitation_intensity_min',
 'precipitation_intensity_max',
 'tn_0',
 'tx_0',
 'nn_decodeText_0',
 'rr_decodeText_0',
 'ff_decodeText_0',
 'tn_1',
 'tx_1',
 'nn_decodeText_1',
 'rr_decodeText_1',
 'ff_decodeText_1',
 'tn_2',
 'tx_2',
 'nn_decodeText_2',
 'rr_decodeText_2',
 'ff_decodeText_2',
 'tn_3',
 'tx_3',
 'nn_decodeText_3',
 'rr_decodeText_3',
 'ff_decodeText_3',
 'tn_4',
 'tx_4',
 'nn_decodeText_4',
 'rr_decodeText_4',
 'ff_decodeText_4',
 'tn_5',
 'tx_5',
 'nn_decodeText_5',
 'rr_decodeText_5',
 'ff_decodeText_5']
''''wwsyn_decodeText_0_RA',
 'wwsyn_decodeText_0_RASN',
 'wwsyn_decodeText_0_SHRA',
 'wwsyn_decodeText_0_SHRASN',
 'wwsyn_decodeText_0_SHSN',
 'wwsyn_decodeText_0_SN',
 'wwsyn_decodeText_0_nil',
 'dd_decodeText_0_E',
 'dd_decodeText_0_N',
 'dd_decodeText_0_NE',
 'dd_decodeText_0_NW',
 'dd_decodeText_0_S',
 'dd_decodeText_0_SE',
 'dd_decodeText_0_SW',
 'dd_decodeText_0_W',
 'dd_decodeText_0_nil',
 'wwsyn_decodeText_1_RA',
 'wwsyn_decodeText_1_RASN',
 'wwsyn_decodeText_1_SHRA',
 'wwsyn_decodeText_1_SHSN',
 'wwsyn_decodeText_1_SN',
 'wwsyn_decodeText_1_nil',
 'dd_decodeText_1_E',
 'dd_decodeText_1_N',
 'dd_decodeText_1_NE',
 'dd_decodeText_1_NW',
 'dd_decodeText_1_S',
 'dd_decodeText_1_SE',
 'dd_decodeText_1_SW',
 'dd_decodeText_1_W',
 'dd_decodeText_1_nil',
 'wwsyn_decodeText_2_RA',
 'wwsyn_decodeText_2_RASN',
 'wwsyn_decodeText_2_SHRA',
 'wwsyn_decodeText_2_SHSN',
 'wwsyn_decodeText_2_SN',
 'wwsyn_decodeText_2_nil',
 'dd_decodeText_2_E',
 'dd_decodeText_2_N',
 'dd_decodeText_2_NE',
 'dd_decodeText_2_NW',
 'dd_decodeText_2_S',
 'dd_decodeText_2_SE',
 'dd_decodeText_2_SW',
 'dd_decodeText_2_W',
 'dd_decodeText_2_nil',
 'wwsyn_decodeText_3_FZRA',
 'wwsyn_decodeText_3_RA',
 'wwsyn_decodeText_3_RASN',
 'wwsyn_decodeText_3_SHRA',
 'wwsyn_decodeText_3_SHSN',
 'wwsyn_decodeText_3_SN',
 'wwsyn_decodeText_3_nil',
 'dd_decodeText_3_E',
 'dd_decodeText_3_N',
 'dd_decodeText_3_NE',
 'dd_decodeText_3_NW',
 'dd_decodeText_3_S',
 'dd_decodeText_3_SE',
 'dd_decodeText_3_SW',
 'dd_decodeText_3_W',
 'dd_decodeText_3_nil',
 'wwsyn_decodeText_4_FZRA',
 'wwsyn_decodeText_4_RA',
 'wwsyn_decodeText_4_RASN',
 'wwsyn_decodeText_4_SHRA',
 'wwsyn_decodeText_4_SHRASN',
 'wwsyn_decodeText_4_SHSN',
 'wwsyn_decodeText_4_SN',
 'wwsyn_decodeText_4_nil',
 'dd_decodeText_4_E',
 'dd_decodeText_4_N',
 'dd_decodeText_4_NE',
 'dd_decodeText_4_NW',
 'dd_decodeText_4_S',
 'dd_decodeText_4_SE',
 'dd_decodeText_4_SW',
 'dd_decodeText_4_W',
 'dd_decodeText_4_nil',
 'wwsyn_decodeText_5_FZRA',
 'wwsyn_decodeText_5_RA',
 'wwsyn_decodeText_5_RASN',
 'wwsyn_decodeText_5_SHRA',
 'wwsyn_decodeText_5_SHSN',
 'wwsyn_decodeText_5_SN',
 'wwsyn_decodeText_5_nil',
 'dd_decodeText_5_E',
 'dd_decodeText_5_ENE',
 'dd_decodeText_5_N',
 'dd_decodeText_5_NE',
 'dd_decodeText_5_NNW',
 'dd_decodeText_5_NW',
 'dd_decodeText_5_S',
 'dd_decodeText_5_SE',
 'dd_decodeText_5_SW',
 'dd_decodeText_5_W',
 'dd_decodeText_5_nil']'''

# %%
# Get the data
aquifer_by_stations = joblib.load('../data/interim/ground-water-and-weather-with-forecasts-and-additional-features.joblib')

# %%
aquifers_list = [85065]
horizon = 5 # prediction horizon
day_len = 365 # number of days to forecast
context_len = 512

# Define the model parameters
# For Torch
'''model = timesfm.TimesFm(
    hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
          num_layers=50,
          use_positional_embedding=False,
          context_len=context_len,
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          #huggingface_repo_id="google/timesfm-1.0-200m-pytorch"),
          huggingface_repo_id="google/timesfm-2.0-500m-jax"),
  )'''

model = timesfm.TimesFm(
      hparams=timesfm.TimesFmHparams(
          backend="gpu",
          per_core_batch_size=32,
          horizon_len=horizon,
      ),
      checkpoint=timesfm.TimesFmCheckpoint(
          huggingface_repo_id="google/timesfm-1.0-200m"),
  )


# List for r2 results for different prediction horizons
r2_scores = [[] for _ in range(horizon)]

for aquifer in aquifers_list:
    # List for storing the predictions
    predictions = [[] for _ in range(5)]

    #scaler = StandardScaler()
    #aquifer_by_stations[aquifer]['altitude_diff'] = scaler.fit_transform(aquifer_by_stations[aquifer]['altitude_diff'].values.reshape(-1, 1))

    # Iterate from day_len days before the end, to the last day
    for i in range(day_len + (horizon-1), 0, -1):
        y = aquifer_by_stations[aquifer]
        
        '''raw_forecast, _ = model.forecast(
          inputs=[y['altitude_diff'][:-i].values.tolist()], freq=[0] * len(y['altitude_diff'][:-i].values.tolist())
        )'''

        covariates = {}
        for j in range(horizon+1):
            for additional_parameter in additional_parameters:
                if j != 0:
                    covariates[additional_parameter][0].append(aquifer_by_stations[aquifer][f'rr_decodeText_{j}'].iloc[-i])
                else:
                    covariates[additional_parameter] = [(aquifer_by_stations[aquifer][f'rr_decodeText_{j}'].iloc[-(context_len+i):-i].values.tolist())]

        cov_forecast, ols_forecast = model.forecast_with_covariates(  
              inputs=[y['altitude_diff'][-(context_len+i):-i].values.tolist()], # Wrap in list since inputs expects list of time series
              dynamic_numerical_covariates= covariates,
              freq=[0] * len(y['altitude_diff'][-(context_len+i):-i].values.tolist()),
              xreg_mode="xreg + timesfm",
              ridge=0,
              force_on_cpu=False,
              normalize_xreg_target_per_input=True    # default
        )

        # Store the results for every prediction horizon separately
        for h in range(horizon):
            #predictions[h].append(scaler.inverse_transform(cov_forecast[0][h].reshape(-1, 1))[0][0])
            predictions[h].append(cov_forecast[0][h])
            #predictions[h].append(raw_forecast[0][h])
    
    for i in range(horizon):
        if i == 0:
            predictions[i] = predictions[i][-day_len:]
        else:
            predictions[i] = predictions[i][(horizon-i-1):-i]

    # Calculate the r2 scores and store them in a list
    for i in range(horizon):
        r2_scores[i].append(r2_score(aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], predictions[i]))

# %%
cov_forecast

# %%
# Calculate the average r2 score
r2_average =  []
std_dev = []

for i in range(horizon):
    r2_average.append(np.mean(r2_scores[i]))
    std_dev.append(np.std(r2_scores[i]))

# %%
r2_average

# %%
plt.figure(figsize=(8, 4))
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], aquifer_by_stations[aquifer]['altitude_diff'][-day_len:], color="royalblue", label="true data")
plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[4], color="tomato", label="forecast0")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[1], color="orange", label="forecast1")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[2], color="green", label="forecast2")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[3], color="purple", label="forecast3")
#plt.plot(aquifer_by_stations[aquifer]['date'][-day_len:], predictions[4], color="brown", label="forecast4")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(covariates['rr_decodeText'][0], color="darkgreen", label="rr_decodeText")
plt.legend()
plt.grid()
plt.show()
